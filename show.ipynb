-- %%
require 'cunn'
-- Out:
-- true

-- %%
net = torch.load('checkpoints/experiment1_9_net_G.t7')

-- %%
dofile('data.lua')

-- %%
batch = getbatch()

-- %%
input_img = batch[{{},3}]

-- %%
input_img = input_img:cuda()

-- %%
output = net:forward(input_img)

-- %%
output:size()
-- Out:
--  128
--    3
--   64
--   64
-- [torch.LongStorage of size 4]

-- %%
itorch.image(output)
-- Out:
-- Console does not support images

-- %%
itorch.image(input_img)
-- Out:
-- Console does not support images
